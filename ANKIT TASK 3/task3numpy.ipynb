# %% [markdown]
# ========TASK 3========
# Task 3.1: NumPy Basics

# %% [markdown]
# 1.	Create a 1D NumPy array of 10 random integers between 1 and 100.

# %%
import numpy as np
arr1=np.random.randint(1,101,size=10)
arr1
# Out:
# array([27, 13,  7, 27, 38, 10,  1, 28, 83, 96], dtype=int32)

# %% [markdown]
# ⦁	Print the maximum element of the array

# %%
print(np.max(arr1))
# Out:
# 96

# %% [markdown]
# ⦁	Print the minimum element of the array.

# %%
print(np.min(arr1))
# Out:
# 1

# %% [markdown]
# ⦁	Print the mean of the array.

# %%
print(np.mean(arr1))
# Out:
# 33.0

# %% [markdown]
# ⦁	Print the sum of all elements.

# %%
print(np.sum(arr1))
# Out:
# 330

# %% [markdown]
# ⦁	Find and print the index of the maximum element.

# %%
print(np.argmax(arr1))
# Out:
# 9

# %% [markdown]
# ⦁	Find and print the index of the minimum element.

# %%
print(np.argmin(arr1))
# Out:
# 6

# %% [markdown]
# ⦁	Sort the array in ascending order and print it.

# %%
print(np.sort(arr1))
# Out:
# [ 1  7 10 13 27 27 28 38 83 96]

# %% [markdown]
# Task 3.2: NumPy Indexing and Slicing
# 1.	Create a 3×3 NumPy array with random integers between 1 and 20.

# %%
arr2=np.random.randint(1,21,size=(3,3))
arr2
# Out:
# array([[17, 14, 13],
#        [ 5, 14, 13],
#        [13, 16,  4]], dtype=int32)

# %% [markdown]
# ⦁	Print the entire array.

# %%
print(arr2)
# Out:
# [[17 14 13]
#  [ 5 14 13]
#  [13 16  4]]

# %% [markdown]
# ⦁	Print the first row of the array.

# %%
arr2[0]
# Out:
# array([17, 14, 13], dtype=int32)

# %% [markdown]
# ⦁	Print the second column of the array.

# %%
arr2[:,1]
# Out:
# array([14, 14, 16], dtype=int32)

# %% [markdown]
# ⦁	Print the element at position (2,2).

# %%
arr2[2,2]
# Out:
# np.int32(4)

# %% [markdown]
# ⦁	Print the sub-array containing the first two rows and first two columns.

# %%
arr2[:2,:2]
# Out:
# array([[17, 14],
#        [ 5, 14]], dtype=int32)

# %% [markdown]
# ⦁	Replace the middle element of the matrix with 99 and print the modified array.

# %%
arr2[1,1]=45
arr2
# Out:
# array([[17, 14, 13],
#        [ 5, 45, 13],
#        [13, 16,  4]], dtype=int32)

# %% [markdown]
# Task 3.3: NumPy Vectorized Operations
# 1.	Generate two random integer arrays of size 10 with values between 1 and 20

# %%
crr=np.random.randint(1,21,size=10)
print("array crr=",crr)
drr=np.random.randint(1,21,size=10)
print("array drr=",drr)
# Out:
# array crr= [13  4 15 17  1  7 18  2  3 14]
# array drr= [ 3 15  3 18  7  7  8  1  7 12]

# %% [markdown]
# ⦁	Perform element-wise addition, subtraction, multiplication, and division between the arrays.

# %%
#addition
crr+drr
# Out:
# array([16, 19, 18, 35,  8, 14, 26,  3, 10, 26], dtype=int32)

# %%
#subtraction
crr-drr
# Out:
# array([ 10, -11,  12,  -1,  -6,   0,  10,   1,  -4,   2], dtype=int32)

# %%
# multiplication
crr*drr
# Out:
# array([ 39,  60,  45, 306,   7,  49, 144,   2,  21, 168], dtype=int32)

# %%
#division
drr/crr
# Out:
# array([0.23076923, 3.75      , 0.2       , 1.05882353, 7.        ,
#        1.        , 0.44444444, 0.5       , 2.33333333, 0.85714286])

# %% [markdown]
# ⦁	Square every element in the first array.

# %%
crr**2
# Out:
# array([169,  16, 225, 289,   1,  49, 324,   4,   9, 196], dtype=int32)

# %% [markdown]
# ⦁	Find the dot product of the two arrays.

# %%
np.dot(crr,drr)
# Out:
# np.int32(841)

# %% [markdown]
# ⦁	Sort the second array in ascending order and print it.

# %%
np.sort(drr)
#for descending order
#np.sort(drr)[::-1]
# Out:
# array([ 1,  3,  3,  7,  7,  7,  8, 12, 15, 18], dtype=int32)
